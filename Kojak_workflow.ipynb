# %%
import pandas as pd
import Kojak_analysis_functions_slick as funcs
import GDELT_loader as loader
big_df = loader.load_csv("data", columns=loader.COLUMNS_TFIDF)
world = funcs.filter_by_continent(big_df, funcs.NORTH_AMERICA)
dfs = funcs.split_df_by_country(world, funcs.NORTH_AMERICA)
# Out:
# Final shape (11906814, 2)

# %%
print 'world', funcs.world_all(world)
print 'United States', funcs.country_all(world, 'United States')
# Out:
# world 6980828
# United States 6697897

# %%
funcs.country_all(world, 'United States')
# Out:
# 6697897

# %%
final_df = funcs.final_df(world, dfs)

# %%
tfs = funcs.tfids_df(final_df)
# Out:
# world: 6980828.0
# Canada 282931.0
# world: 6980828.0
# United States 6697897.0

# %%
tfs
# Out:
#                                                                           Canada  \
# EVENTDESCRIPTION
# Abduct, hijack, or take hostage                                         0.615815
# Accede to demands for change in institutions, regime                    0.166337
# Accede to demands for change in leadership                              1.337607
# Accede to demands for rights                                            1.138075
# Accede to requests or demands for political reform not specified below  0.360801
# Accuse of aggression                                                    0.754543
# Accuse of crime, corruption                                             1.572658
# Accuse of espionage, treason                                            0.377267
# Accuse of human rights abuses                                           0.389578
# Accuse of war crimes                                                    0.762036
# Accuse, not specified below                                             1.053869
# Acknowledge or claim responsibility                                     0.899680
# Allow delivery of humanitarian aid                                      0.379588
# Allow international involvement not specified below                     0.750042
# Apologize                                                               1.150406
# Appeal for aid, not specified below                                     1.338279
# Appeal for change in institutions, regime                                    NaN
# Appeal for change in leadership                                         1.054778
# Appeal for de-escalation of military engagement                         0.647746
# Appeal for diplomatic cooperation, such as policy support               0.828197
# Appeal for easing of administrative sanctions                                NaN
# Appeal for easing of economic sanctions, boycott, or embargo                 NaN
# Appeal for economic aid                                                 1.011804
# Appeal for economic cooperation                                         1.074047
# Appeal for humanitarian aid                                             1.095709
# Appeal for intelligence                                                 1.370255
# Appeal for judicial cooperation                                         0.990532
# Appeal for material cooperation, not specified below                    0.585671
# Appeal for military aid                                                 0.988959
# Appeal for military cooperation                                              NaN
# ...                                                                          ...
# Return, release person(s)                                               1.271265
# Return, release property                                                0.882204
# Return, release, not specified below                                    1.208611
# Seize or damage property, not specified below                           0.841373
# Sexually assault                                                        0.605600
# Share intelligence or information                                       0.672088
# Sign formal agreement                                                   0.778397
# Threaten conventional attack                                            1.135708
# Threaten non-force, not specified below                                 0.588167
# Threaten occupation                                                          NaN
# Threaten political dissent, protest                                     1.501977
# Threaten to ban political parties or politicians                             NaN
# Threaten to boycott, embargo, or sanction                               1.089254
# Threaten to halt international involvement (non-mediation)              2.114850
# Threaten to halt negotiations                                           0.161474
# Threaten to reduce or break relations                                   0.876715
# Threaten to reduce or stop aid                                          0.290274
# Threaten to use military force, not specified below                     1.132847
# Threaten unconventional violence                                        0.870411
# Threaten with administrative sanctions, not specified below             1.682267
# Threaten with violent repression                                        0.322526
# Threaten, not specified below                                           1.252184
# Torture                                                                 1.035371
# Use as human shield                                                     1.007072
# Use conventional military force, not specified below                    0.981392
# Use tactics of violent repression                                       0.709613
# Use unconventional violence, not specified below                        1.257377
# Veto                                                                    0.686974
# Violate ceasefire                                                       1.538517
# Yield, not specified below                                              0.998118
#
#                                                                         United States
# EVENTDESCRIPTION
# Abduct, hijack, or take hostage                                              1.016229
# Accede to demands for change in institutions, regime                         1.035215
# Accede to demands for change in leadership                                   0.985739
# Accede to demands for rights                                                 0.994167
# Accede to requests or demands for political reform not specified below       1.027001
# Accuse of aggression                                                         1.010369
# Accuse of crime, corruption                                                  0.975810
# Accuse of espionage, treason                                                 1.026305
# Accuse of human rights abuses                                                1.025785
# Accuse of war crimes                                                         1.010052
# Accuse, not specified below                                                  0.997724
# Acknowledge or claim responsibility                                          1.004238
# Allow delivery of humanitarian aid                                           1.026207
# Allow international involvement not specified below                          1.010559
# Apologize                                                                    0.993647
# Appeal for aid, not specified below                                          0.985710
# Appeal for change in institutions, regime                                    1.042242
# Appeal for change in leadership                                              0.997686
# Appeal for de-escalation of military engagement                              1.014880
# Appeal for diplomatic cooperation, such as policy support                    1.007257
# Appeal for easing of administrative sanctions                                1.042242
# Appeal for easing of economic sanctions, boycott, or embargo                 1.042242
# Appeal for economic aid                                                      0.999501
# Appeal for economic cooperation                                              0.996872
# Appeal for humanitarian aid                                                  0.995957
# Appeal for intelligence                                                      0.984360
# Appeal for judicial cooperation                                              1.000400
# Appeal for material cooperation, not specified below                         1.017502
# Appeal for military aid                                                      1.000466
# Appeal for military cooperation                                              1.042242
# ...                                                                               ...
# Return, release person(s)                                                    0.988541
# Return, release property                                                     1.004976
# Return, release, not specified below                                         0.991188
# Seize or damage property, not specified below                                1.006701
# Sexually assault                                                             1.016660
# Share intelligence or information                                            1.013852
# Sign formal agreement                                                        1.009361
# Threaten conventional attack                                                 0.994267
# Threaten non-force, not specified below                                      1.017397
# Threaten occupation                                                          1.042242
# Threaten political dissent, protest                                          0.978796
# Threaten to ban political parties or politicians                             1.042242
# Threaten to boycott, embargo, or sanction                                    0.996230
# Threaten to halt international involvement (non-mediation)                   0.952907
# Threaten to halt negotiations                                                1.035421
# Threaten to reduce or break relations                                        1.005208
# Threaten to reduce or stop aid                                               1.029980
# Threaten to use military force, not specified below                          0.994388
# Threaten unconventional violence                                             1.005474
# Threaten with administrative sanctions, not specified below                  0.971180
# Threaten with violent repression                                             1.028618
# Threaten, not specified below                                                0.989347
# Torture                                                                      0.998506
# Use as human shield                                                          0.999701
# Use conventional military force, not specified below                         1.000786
# Use tactics of violent repression                                            1.012266
# Use unconventional violence, not specified below                             0.989128
# Veto                                                                         1.013223
# Violate ceasefire                                                            0.977252
# Yield, not specified below                                                   1.000080
#
# [244 rows x 2 columns]
